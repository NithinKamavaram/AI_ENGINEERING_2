# %%
from langchain_community.document_loaders import PDFMinerPDFasHTMLLoader, AzureAIDocumentIntelligenceLoader, PyMuPDFLoader, PyPDFLoader
from langchain_community.docstore.document import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings
from bs4 import BeautifulSoup
from langchain_community.vectorstores import Qdrant
from langchain.retrievers import ParentDocumentRetriever, ContextualCompressionRetriever, SelfQueryRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor, LLMChainFilter, DocumentCompressorPipeline
from langchain.storage import InMemoryStore
from langchain_openai import OpenAI, ChatOpenAI
from langchain.chains.query_constructor.base import AttributeInfo
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain import hub
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
import re
import os
import openai
from getpass import getpass
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough
from ragas.testset.generator import TestsetGenerator
import os
from ragas.testset.evolutions import simple, reasoning, multi_context

# %%
openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
loader = PyPDFLoader("meta_10k.pdf")
documents = loader.load()

# %%
text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=1000,
    chunk_overlap=100
)
texts = text_splitter.split_documents(documents)

# %%
len(texts)
# Out:
# 147

# %%
embeddings_model = OpenAIEmbeddings(model = "text-embedding-3-small")

# %%
qdrant = Qdrant.from_documents(texts, embeddings_model, location=":memory:", collection_name = '10K_RAG', force_recreate=True)
qdrant

# %%
qdrant_retriever = qdrant.as_retriever()
qdrant_retriever
# Out:
# VectorStoreRetriever(tags=['Qdrant', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.qdrant.Qdrant object at 0x139c7bf50>)

# %%
llm = ChatOpenAI(temperature=0)
llm.model_name
# Out:
# 'gpt-3.5-turbo'

# %%
template = """You are an helpful assistant for question-answering tasks, specifically you are an expert in answering SEC 10-K report questions.
If you  don't know the answer, just say that you don't know.
Answer based on the context given to you, for a given question.

Context:
{context}

Question:
{question}

Answer:"""

rag_chat_prompt = ChatPromptTemplate.from_template(template)
print(rag_chat_prompt.messages[0].prompt.template)
# Out:
# You are an helpful assistant for question-answering tasks, specifically you are an expert in answering SEC 10-K report questions.
# If you  don't know the answer, just say that you don't know.
# Answer based on the context given to you, for a given question.
#
# Context:
# {context}
#
# Question:
# {question}
#
# Answer:

# %%
base_chain = (
    {"context": itemgetter("question") | qdrant_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_chat_prompt | llm, "context": itemgetter("context")}
)

# %%
query1 = "What was the total value of 'Cash and cash equivalents' as of December 31, 2023?"
query2 = "Who are Meta's 'Directors' (i.e., members of the Board of Directors)?"

# %%
query1_result = base_chain.invoke({"question": query1})
query2_result = base_chain.invoke({"question": query2})

# %%
print(query1_result['response'].content)
print("*******")
print(query2_result['response'].content)
# Out:
# The total value of 'Cash and cash equivalents' as of December 31, 2023, was $41.862 billion.
# *******
# Meta's Board of Directors includes individuals who oversee strategic and business risk management. The Audit & Risk Oversight Committee of the board is responsible for cybersecurity risk management oversight, while the Privacy Committee oversees privacy and data use risks. Management is responsible for identifying, assessing, and managing material cybersecurity risks. The Chief Information Security Officer (CISO), Guy Rosen, leads the cybersecurity program at Meta.

# %%
loader = PyMuPDFLoader("meta_10k.pdf")
documents_eval = loader.load()

# %%
text_splitter_eval = RecursiveCharacterTextSplitter(chunk_size = 4250, chunk_overlap = 100)
texts_eval = text_splitter_eval.split_documents(documents_eval)

# %%
generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
critic_llm = ChatOpenAI(model="gpt-3.5-turbo")
embeddings = OpenAIEmbeddings()

generator_test = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

distributions = {
    simple: 0.4,
    multi_context: 0.4,
    reasoning: 0.2
}

testset = generator_test.generate_with_langchain_docs(documents_eval, 12, distributions, is_async = False)
testset.to_pandas()
# Out:
# embedding nodes:   0%|          | 0/346 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/12 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the purpose of the facilities consolid...
# 1   What acquisitions did the company make, includ...
# 2   What types of claims and lawsuits have been fi...
# 3   How are accounts receivable recorded and carri...
# 4   What are some areas in which government author...
# 5   What are the consequences for a company's repu...
# 6   What is the revenue recognition basis at Meta ...
# 7   What are the potential impacts on our products...
# 8   How are gains or losses in interest and other ...
# 9   How does the conversion of Class B common stoc...
# 10  What are the potential consequences of cyber-a...
# 11  What legal actions has the FTC taken regarding...
#
#                                              contexts  \
# 0   [Table of Contents\nWe also recorded $1.76 bil...
# 1   [, including by acquiring Instagram in 2012 an...
# 2   [ litigation and other proceedings that were f...
# 3   [Table of Contents\nidentification method and ...
# 4   [ New legislation or regulatory decisions that...
# 5   [Table of Contents\nPayment-related activities...
# 6   [Table of Contents\nMETA PLATFORMS, INC.\nNOTE...
# 7   [Table of Contents\n•\nuser behavior on any of...
# 8   [Table of Contents\nidentification method and ...
# 9   [Table of Contents\nNote 4. Earnings per Share...
# 10  [Table of Contents\nmay attempt to fraudulentl...
# 11  [, including by acquiring Instagram in 2012 an...
#
#                                          ground_truth evolution_type  \
# 0   The purpose of the facilities consolidation re...         simple
# 1   The company made several acquisitions, includi...         simple
# 2   Putative class actions have been filed in the ...         simple
# 3   Accounts receivable are recorded and carried a...         simple
# 4   government authorities and regulators are inve...         simple
# 5   Security breaches, improper access to or discl...  multi_context
# 6   Meta Platforms, Inc. recognizes revenue under ...  multi_context
# 7   The potential impacts on our products and serv...  multi_context
# 8   We include gains or losses in interest and oth...  multi_context
# 9   The conversion of Class B common stock to Clas...  multi_context
# 10  The potential consequences of cyber-attacks on...      reasoning
# 11  The FTC has taken legal actions against the co...      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 1   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 2   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 3   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 4   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 5   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 6   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 7   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 8   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 9   [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 10  [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True
# 11  [{'source': 'meta_10k.pdf', 'file_path': 'meta...          True

# %%
test_df = testset.to_pandas()

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %%
answers = []
contexts = []

for question in test_questions:
  response = base_chain.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])
  print('Question: ' + question)
  print('Answer: ' + response["response"].content)
  print("****")
# Out:
# Question: What is the purpose of the facilities consolidation restructuring efforts mentioned in the context?
# Answer: The purpose of the facilities consolidation restructuring efforts mentioned in the context is to pursue greater efficiency and realign the business and strategic priorities of the company. This includes subleasing, early terminating, or abandoning several office buildings under operating leases, as well as a pivot towards a next-generation data center design.
# ****
# Question: What acquisitions did the company make, including acquiring Instagram?
# Answer: The company made acquisitions including acquiring Instagram in 2012 and WhatsApp in 2014.
# ****
# Question: What types of claims and lawsuits have been filed regarding the alleged "social media addiction" caused by Facebook and Instagram?
# Answer: Multiple putative class actions have been filed in various federal and state courts alleging that Facebook and Instagram cause "social media addiction" in users, with most proceedings focused on those under 18 years old, resulting in various mental health and other harms. These lawsuits seek damages and injunctive relief, including cases filed by various state attorneys general in In re Social Media Adolescent Addiction Product Liability Personal Injury Litigation.
# ****
# Question: How are accounts receivable recorded and carried on the financial statements?
# Answer: Accounts receivable are recorded and carried at the original invoiced amount less an allowance for any potential uncollectible amounts. Estimates of expected credit and collectibility trends for the allowance for credit losses are made and expensed as incurred on the consolidated statements of income.
# ****
# Question: What are some areas in which government authorities and regulators are investigating the use of AI by the company?
# Answer: Government authorities and regulators are investigating the company's use of AI in various areas such as privacy, data use and data protection, processing of sensitive data, data for advertising purposes, data security, minors, safety, law enforcement, consumer protection, civil rights, content moderation, use of the platform for illegal activities, competition, AI, and machine learning.
# ****
# Question: What are the consequences for a company's reputation and business if it experiences cyber incidents and how do these incidents relate to the company's payments functionality and data security measures?
# Answer: The consequences for a company's reputation and business if it experiences cyber incidents include harm to reputation, adverse effects on user trust and engagement, negative impact on financial results, and potential legal or regulatory actions. These incidents can also lead to interruptions in services, degradation of user experience, loss of user confidence, and financial harm.
#
# In the context of the company's payments functionality and data security measures, cyber incidents pose a significant risk. The company's Payments products involve the collection, storage, processing, and transmission of a large amount of data, including personal information and payment information. Any failure to prevent or mitigate security breaches and improper access to this data could result in loss, modification, disclosure, or misuse of such data, harming the business and reputation. Additionally, cyber-attacks targeting the company's Payments infrastructure could lead to financial penalties, product changes, or other adverse effects on the business and financial results.
# ****
# Question: What is the revenue recognition basis at Meta Platforms, Inc. and which segments contribute to their financial results?
# Answer: The revenue recognition basis at Meta Platforms, Inc. is in accordance with Accounting Standards Codification (ASC) 606 Revenue From Contracts With Customers. Revenue is recognized when control of the promised goods or services is transferred to customers, reflecting the consideration expected in exchange for those goods or services.
#
# Meta Platforms, Inc. reports their financial results based on two reportable segments: Family of Apps (FoA) and Reality Labs (RL). These segments align with how the chief operating decision maker (CODM), who is the CEO, reviews and manages the business. The company generates the majority of its revenue from advertising.
# ****
# Question: What are the potential impacts on our products and services due to changes in user behavior, engagement with our platform, advertising practices, and marketer satisfaction?
# Answer: The potential impacts on our products and services due to changes in user behavior, engagement with our platform, advertising practices, and marketer satisfaction include:
# - Decreased user retention, growth, and engagement, particularly for revenue-generating products like Facebook and Instagram, which could adversely affect revenue and financial results.
# - Loss of marketers or reduction in spending by marketers, which could seriously harm our business as substantially all of our revenue is generated from advertising on Facebook and Instagram.
# - Adverse effects on advertising revenue due to factors such as decreases in user engagement, changes in user access and engagement with our products, product changes affecting ad display, limitations on ad delivery, and changes in ad pricing or demand.
# - Impact on ad targeting and measurement tools due to regulatory developments, changes in data signal availability, and limitations imposed by mobile operating system and browser providers, which could negatively affect advertising revenue.
# - Potential negative effects on revenue and financial results if user perception of our products as useful, reliable, and trustworthy diminishes, leading to difficulty in attracting or retaining users and maintaining user engagement levels.
# ****
# Question: How are gains or losses in interest and other income (expense), net accounted for in the consolidated statements of income, considering the fair value hierarchy and the measurement alternative for non-marketable equity securities?
# Answer: Gains or losses in interest and other income (expense), net related to non-marketable equity securities accounted for using the measurement alternative are recognized in the consolidated statements of income. When indicators of impairment exist and the estimated fair value of an investment is below the carrying amount, the investment is written down to fair value. The change in carrying value, including any gains or losses resulting from the remeasurements, is then recognized in interest and other income (expense), net on the consolidated statements of income. This accounting treatment aligns with the fair value hierarchy, specifically Level 3, as it involves significant unobservable inputs to estimate the fair value of non-marketable equity securities.
# ****
# Question: How does the conversion of Class B common stock to Class A common stock and the inclusion of RSUs awards under the Equity Incentive Plan affect the weighted-average number of shares used in the computation of basic and diluted earnings per share?
# Answer: The conversion of Class B common stock to Class A common stock and the inclusion of RSUs awards under the Equity Incentive Plan affect the weighted-average number of shares used in the computation of basic and diluted earnings per share by increasing the total number of shares outstanding. This increase in shares impacts the denominator in the EPS calculation, resulting in a lower EPS figure due to the dilution effect of additional shares.
# ****
# Question: What are the potential consequences of cyber-attacks on the company's business, reputation, or financial results, considering factors such as evolving sophistication and volume of attacks, difficulty in detection, limitations of data protection measures, involvement of third parties, significant costs in protection, legal and regulatory actions, decline in user base or engagement, and intentional misuse of services and user data?
# Answer: The potential consequences of cyber-attacks on the company's business, reputation, or financial results include:
# 1. Difficulty in detecting sophisticated and evolving cyber-attacks, leading to potential long periods of undetected breaches.
# 2. Limitations of data protection measures may result in data loss, misuse, or improper access to user data.
# 3. Involvement of third parties in storing or handling data may lead to improper access, use, or disclosure of company or user data.
# 4. Significant costs incurred in protecting against and remediating cyber incidents.
# 5. Legal and regulatory actions by affected users or government authorities due to security breaches, potentially resulting in fines, costs, or consent decrees.
# 6. Decline in active user base or engagement levels due to security incidents, impacting the company's business and financial results.
# 7. Intentional misuse of services and user data by third parties may adversely affect the company's reputation and brands.
# Overall, these consequences highlight the potential negative impact of cyber-attacks on the company's operations and overall performance.
# ****
# Question: What legal actions has the FTC taken regarding the company's alleged antitrust violations in relation to Instagram and WhatsApp acquisitions?
# Answer: The FTC filed a complaint against the company in the U.S. District Court for the District of Columbia alleging anticompetitive conduct and unfair methods of competition in violation of Section 5 of the Federal Trade Commission Act and Section 2 of the Sherman Act. The FTC sought a permanent injunction against the company's alleged violations of the antitrust laws, as well as other equitable relief, including divestiture or reconstruction of Instagram and WhatsApp. The court granted the company's motion to dismiss the initial complaint but denied the motion to dismiss the amended complaint. Multiple putative class actions have also been filed against the company alleging violations of antitrust laws in connection with these acquisitions.
# ****

# %%
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
response_dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'contexts', 'ground_truth'],
#     num_rows: 12
# })

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
results_baseline = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]

# %%
results_baseline
# Out:
# {'faithfulness': 1.0000, 'answer_relevancy': 0.9463, 'context_recall': 0.9474, 'context_precision': 0.9606, 'answer_correctness': 0.7568}

# %%
results_baseline = results_baseline.to_pandas()
results_baseline
# Out:
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
#                                              question  \
# 0   What is the purpose of the facilities consolid...
# 1   What acquisitions did the company make, includ...
# 2   What types of claims and lawsuits have been fi...
# 3   How are accounts receivable recorded and carri...
# 4   What are some areas in which government author...
# 5   What are the consequences for a company's repu...
# 6   What is the revenue recognition basis at Meta ...
# 7   What are the potential impacts on our products...
# 8   How are gains or losses in interest and other ...
# 9   How does the conversion of Class B common stoc...
# 10  What are the potential consequences of cyber-a...
# 11  What legal actions has the FTC taken regarding...
#
#                                                answer  \
# 0   The purpose of the facilities consolidation re...
# 1   The company made acquisitions including acquir...
# 2   Multiple putative class actions have been file...
# 3   Accounts receivable are recorded and carried a...
# 4   Government authorities and regulators are inve...
# 5   The consequences for a company's reputation an...
# 6   The revenue recognition basis at Meta Platform...
# 7   The potential impacts on our products and serv...
# 8   Gains or losses in interest and other income (...
# 9   The conversion of Class B common stock to Clas...
# 10  The potential consequences of cyber-attacks on...
# 11  The FTC filed a complaint against the company ...
#
#                                              contexts  \
# 0   [Table of Contents\nNote 3. Restructuring\n202...
# 1   [Table of Contents\nThese laws and regulations...
# 2   [Table of Contents\nthe Sherman Act, including...
# 3   [Table of Contents\nidentification method and ...
# 4   [Table of Contents\nIf our new products or cha...
# 5   [Table of Contents\nPayment-related activities...
# 6   [Table of Contents\nMETA PLATFORMS, INC.\nNOTE...
# 7   [Table of Contents\n•third-party initiatives t...
# 8   [Table of Contents\nidentification method and ...
# 9   [Table of Contents\nNote 4. Earnings per Share...
# 10  [Table of Contents\nmay attempt to fraudulentl...
# 11  [Table of Contents\nThese laws and regulations...
#
#                                          ground_truth  faithfulness  \
# 0   The purpose of the facilities consolidation re...           1.0
# 1   The company made several acquisitions, includi...           1.0
# 2   Putative class actions have been filed in the ...           1.0
# 3   Accounts receivable are recorded and carried a...           1.0
# 4   government authorities and regulators are inve...           1.0
# 5   Security breaches, improper access to or discl...           1.0
# 6   Meta Platforms, Inc. recognizes revenue under ...           1.0
# 7   The potential impacts on our products and serv...           1.0
# 8   We include gains or losses in interest and oth...           1.0
# 9   The conversion of Class B common stock to Clas...           1.0
# 10  The potential consequences of cyber-attacks on...           1.0
# 11  The FTC has taken legal actions against the co...           1.0
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           1.000000        1.000000           0.805556            0.225313
# 1           0.920075        1.000000           0.916667            0.739880
# 2           0.938838        1.000000           1.000000            0.810364
# 3           0.983201        1.000000           0.805556            0.740012
# 4           0.977872        1.000000           1.000000            0.829834
# 5           0.950771        1.000000           1.000000            0.860306
# 6           0.963448        1.000000           1.000000            0.648836
# 7           0.889799        0.368421           1.000000            0.918912
# 8           0.944434        1.000000           1.000000            0.804831
# 9           0.993349        1.000000           1.000000            0.622546
# 10          0.938213        1.000000           1.000000            0.995729
# 11          0.855624        1.000000           1.000000            0.885395

# %%
loader = PyMuPDFLoader("meta_10k.pdf")
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 4250, chunk_overlap = 100)
texts = text_splitter.split_documents(documents)
embeddings_model = OpenAIEmbeddings(model = "text-embedding-3-large")
qdrant = Qdrant.from_documents(texts, embeddings_model, location=":memory:", collection_name = '10K_RAG', force_recreate=True)
qdrant
qdrant_retriever = qdrant.as_retriever()
qdrant_retriever
llm = ChatOpenAI(temperature=0)
llm.model_name
metadata_field_info = [
]

document_content_desc = "Form 10-K annual report required by the U.S. Securities and Exchange Commission (SEC), that gives a comprehensive summary of a company's financial performance for company Meta for year 2023"

self_query_retriever = SelfQueryRetriever.from_llm(llm,
                                                   qdrant, 
                                                   document_content_desc, 
                                                   metadata_field_info)
template = """You are an helpful assistant for question-answering tasks, specifically you are an expert in answering SEC 10-K report questions.
If you  don't know the answer, just say that you don't know.
Answer based on the context given to you, for a given question.

Context:
{context}

Question:
{question}

Answer:"""

rag_chat_prompt = ChatPromptTemplate.from_template(template)
print(rag_chat_prompt.messages[0].prompt.template)
rag_qa_chain_sqr =  (
    {"context": itemgetter("question") | self_query_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_chat_prompt | llm, "context": itemgetter("context")}
)
# Out:
# You are an helpful assistant for question-answering tasks, specifically you are an expert in answering SEC 10-K report questions.
# If you  don't know the answer, just say that you don't know.
# Answer based on the context given to you, for a given question.
#
# Context:
# {context}
#
# Question:
# {question}
#
# Answer:

# %%
query1_result = rag_qa_chain_sqr.invoke({"question": query1})
query2_result = rag_qa_chain_sqr.invoke({"question": query2})

# %%
print(query1_result['response'].content)
print("*******")
print(query2_result['response'].content)
# Out:
# The total value of 'Cash and cash equivalents' as of December 31, 2023, was $41,862 million.
# *******
# The directors of Meta (formerly Facebook) as per the SEC 10-K report are:
# 1. Mark Zuckerberg
# 2. Susan Li
# 3. Aaron Anderson
# 4. Peggy Alford
# 5. Marc L. Andreessen
# 6. Andrew W. Houston
# 7. Nancy Killefer
# 8. Robert M. Kimmitt
# 9. Sheryl K. Sandberg
# 10. Tracey T. Travis
# 11. Tony Xu

# %%
answers = []
contexts = []

for question in test_questions:
  response = rag_qa_chain_sqr.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])
  print('Question: ' + question)
  print('Answer: ' + response["response"].content)
  print("****")
# Out:
# Question: What is the purpose of the facilities consolidation restructuring efforts mentioned in the context?
# Answer: The purpose of the facilities consolidation restructuring efforts mentioned in the context is to pursue greater efficiency and realign the company's business and strategic priorities. This includes subleasing, early terminating, or abandoning several office buildings under operating leases to streamline operations and reduce costs.
# ****
# Question: What acquisitions did the company make, including acquiring Instagram?
# Answer: The company made acquisitions including acquiring Instagram in 2012 and WhatsApp in 2014.
# ****
# Question: What types of claims and lawsuits have been filed regarding the alleged "social media addiction" caused by Facebook and Instagram?
# Answer: Multiple types of claims and lawsuits have been filed regarding the alleged "social media addiction" caused by Facebook and Instagram. These include putative class actions, derivative actions, public nuisance claims, and lawsuits alleging violations of securities laws, breach of fiduciary duties, and other causes of action. Additionally, claims have been made regarding violations of the Children's Online Privacy Protection Act (COPPA) and violations of state laws concerning consumer protection, unfair business practices, and products liability. These lawsuits seek damages and injunctive relief and involve various federal and state courts as well as government investigations and requests from regulators.
# ****
# Question: How are accounts receivable recorded and carried on the financial statements?
# Answer: Accounts receivable are recorded and carried at the original invoiced amount less an allowance for any potential uncollectible amounts. The company makes estimates of expected credit and collectibility trends for the allowance for credit losses.
# ****
# Question: What are some areas in which government authorities and regulators are investigating the use of AI by the company?
# Answer: Government authorities and regulators are investigating the company's use of AI in areas such as privacy, data use and data protection, processing of sensitive data, data for advertising purposes, data security, minors, safety, law enforcement, consumer protection, civil rights, content moderation, use of the platform for illegal or objectionable activity, competition, AI, and machine learning.
# ****
# Question: What are the consequences for a company's reputation and business if it experiences cyber incidents and how do these incidents relate to the company's payments functionality and data security measures?
# Answer: The consequences for a company's reputation and business if it experiences cyber incidents include negative effects on user trust and engagement, harm to the company's reputation and brands, changes to business practices adverse to the business, and adverse effects on business and financial results. These incidents can also lead to additional litigation.
#
# These incidents are related to the company's payments functionality as they can result in increased costs, diversion of management time and attention, and other resources to address bad transactions or customer disputes. Additionally, potential fraudulent or illegal activity by users, developers, employees, or third parties can occur, impacting the company's payments transactions.
#
# Furthermore, these incidents are also related to the company's data security measures as security breaches, improper access to or disclosure of data, hacking, phishing attacks, and other cyber incidents can harm the company's reputation and adversely affect its business. The company's efforts to protect its data and user data, prevent security breaches, and mitigate risks may not provide absolute security, leading to financial harm, interruptions in services, and loss of user trust.
# ****
# Question: What is the revenue recognition basis at Meta Platforms, Inc. and which segments contribute to their financial results?
# Answer: The revenue recognition basis at Meta Platforms, Inc. is primarily based on the delivery of advertising services. The segments that contribute to their financial results include the Family of Apps, Reality Labs, and Facebook Financial.
# ****
# Question: What are the potential impacts on our products and services due to changes in user behavior, engagement with our platform, advertising practices, and marketer satisfaction?
# Answer: The potential impacts on products and services due to changes in user behavior, engagement with the platform, advertising practices, and marketer satisfaction include:
# - Decreases in user engagement and time spent on products
# - Reduction in user access and engagement with products
# - Changes in product features affecting ad display and content sharing
# - Decrease in marketer demand or pricing of ads
# - Reduction in quantity or quality of ads shown to users
# - Loss of advertising market share to competitors
# - Limitations on offering significant products in certain regions
# - Changes in user sentiment affecting product perception
# - Inability to maintain or grow user engagement with integrated applications
# - Adoption of new technologies displacing products
# - Adverse effects of legislation, regulations, or litigation on products
# - Decreased engagement with products due to changes in terms of service
# - Technical problems affecting product delivery and user experience
# - Negative perception of policies or actions related to sharing, content, or advertising
# - Focus on longer-term initiatives impacting near-term user growth
# - Changes in user account login processes or product promotion strategies
# - Unsuccessful initiatives to attract and retain users and engagement
#
# These factors can collectively impact the attractiveness and effectiveness of products and services, potentially leading to a decline in revenue and financial results.
# ****
# Question: How are gains or losses in interest and other income (expense), net accounted for in the consolidated statements of income, considering the fair value hierarchy and the measurement alternative for non-marketable equity securities?
# Answer: Gains or losses in interest and other income (expense), net related to non-marketable equity securities accounted for using the measurement alternative are recognized in the interest and other income (expense), net on the consolidated statements of income. This recognition occurs when indicators of impairment exist and the estimated fair value of an investment is below the carrying amount, leading to a write-down of the investment to fair value. The change in carrying value, along with any gains or losses resulting from the remeasurements, are reflected in the interest and other income (expense), net section of the consolidated statements of income.
# ****
# Question: How does the conversion of Class B common stock to Class A common stock and the inclusion of RSUs awards under the Equity Incentive Plan affect the weighted-average number of shares used in the computation of basic and diluted earnings per share?
# Answer: The conversion of Class B common stock to Class A common stock and the inclusion of RSUs awards under the Equity Incentive Plan affect the weighted-average number of shares used in the computation of basic and diluted earnings per share by increasing the total number of shares outstanding. This increase in shares impacts the denominator of the EPS calculation, leading to a lower EPS value due to the dilution effect caused by the additional shares.
# ****
# Question: What are the potential consequences of cyber-attacks on the company's business, reputation, or financial results, considering factors such as evolving sophistication and volume of attacks, difficulty in detection, limitations of data protection measures, involvement of third parties, significant costs in protection, legal and regulatory actions, decline in user base or engagement, and intentional misuse of services and user data?
# Answer: The potential consequences of cyber-attacks on the company's business, reputation, or financial results include negative effects on user trust and engagement, harm to the company's reputation and brands, changes to business practices adverse to the company, adverse effects on business and financial results, significant costs in protecting against or remediating such incidents, legal and regulatory actions leading to fines, orders, or consent decrees modifying business practices, decline in active user base or engagement levels, and intentional misuse of services and user data adversely affecting the company's business.
# ****
# Question: What legal actions has the FTC taken regarding the company's alleged antitrust violations in relation to Instagram and WhatsApp acquisitions?
# Answer: I don't know.
# ****

# %%
response_dataset_advanced_retrieval = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
results_advanced= evaluate(response_dataset_advanced_retrieval, metrics)
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]

# %%
results_advanced
# Out:
# {'faithfulness': 1.0000, 'answer_relevancy': 0.9551, 'context_recall': 0.9825, 'context_precision': 0.8657, 'answer_correctness': 0.6368}

# %%
results_advanced = results_advanced.to_pandas()
results_advanced
# Out:
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
#                                              question  \
# 0   What is the purpose of the facilities consolid...
# 1   What acquisitions did the company make, includ...
# 2   What types of claims and lawsuits have been fi...
# 3   How are accounts receivable recorded and carri...
# 4   What are some areas in which government author...
# 5   What are the consequences for a company's repu...
# 6   What is the revenue recognition basis at Meta ...
# 7   What are the potential impacts on our products...
# 8   How are gains or losses in interest and other ...
# 9   How does the conversion of Class B common stoc...
# 10  What are the potential consequences of cyber-a...
# 11  What legal actions has the FTC taken regarding...
#
#                                                answer  \
# 0   The purpose of the facilities consolidation re...
# 1   The company made acquisitions of Instagram in ...
# 2   Multiple types of claims and lawsuits have bee...
# 3   Accounts receivable are recorded and carried a...
# 4   Government authorities and regulators are inve...
# 5   Cyber incidents can have significant consequen...
# 6   The revenue recognition basis at Meta Platform...
# 7   The potential impacts on products and services...
# 8   Gains or losses in interest and other income (...
# 9   The conversion of Class B common stock to Clas...
# 10  The potential consequences of cyber-attacks on...
# 11  The FTC filed a complaint against the company ...
#
#                                              contexts  \
# 0   [Table of Contents\nNote 3. Restructuring\n202...
# 1   [Europe, and other jurisdictions. Such investi...
# 2   [and certain of our directors and officers all...
# 3   [other unobservable inputs including volatilit...
# 4   [cybersecurity attacks, data privacy violation...
# 5   [Table of Contents\nPayment-related activities...
# 6                                                  []
# 7   [Table of Contents\neffectiveness of advertisi...
# 8   [Table of Contents\nidentification method and ...
# 9   [Table of Contents\nNote 4. Earnings per Share...
# 10  [general hacking continue to be prevalent in o...
# 11  [Europe, and other jurisdictions. Such investi...
#
#                                          ground_truth  faithfulness  \
# 0   The purpose of the facilities consolidation re...           1.0
# 1   The company made several acquisitions, includi...           1.0
# 2   Putative class actions have been filed in the ...           1.0
# 3   Accounts receivable are recorded and carried a...           1.0
# 4   government authorities and regulators are inve...           1.0
# 5   Security breaches, improper access to or discl...           1.0
# 6   Meta Platforms, Inc. recognizes revenue under ...           1.0
# 7   The potential impacts on our products and serv...           1.0
# 8   We include gains or losses in interest and oth...           1.0
# 9   The conversion of Class B common stock to Clas...           1.0
# 10  The potential consequences of cyber-attacks on...           1.0
# 11  The FTC has taken legal actions against the co...           1.0
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           1.000000        1.000000           0.805556            0.225233
# 1           0.885400        1.000000           1.000000            0.613656
# 2           0.999583        1.000000           1.000000            0.596731
# 3           0.983201        1.000000           0.583333            0.614254
# 4           0.985153        1.000000           1.000000            0.829877
# 5           0.902844        1.000000           1.000000            0.790593
# 6           0.955150        1.000000           0.000000            0.653773
# 7           0.981549        0.789474           1.000000            0.613446
# 8           0.949148        1.000000           1.000000            0.742821
# 9           1.000000        1.000000           1.000000            0.622304
# 10          0.957704        1.000000           1.000000            0.721876
# 11          0.861343        1.000000           1.000000            0.617548

# %%
results_advanced_large= evaluate(response_dataset_advanced_retrieval, metrics)
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# No statements were generated from the answer.
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2275' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2260' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2301' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2294' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2287' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2310' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2281' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2311' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2305' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2298' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2292' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2270' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2286' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2278' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2303' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-2274' coro=<as_completed.<locals>.sema_coro() running at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/ragas/executor.py:38> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/futures.py:387, Task.task_wakeup()]> cb=[as_completed.<locals>._on_completion() at /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/asyncio/tasks.py:602]>

# %%
results_advanced_large
# Out:
# {'faithfulness': 0.9870, 'answer_relevancy': 0.8886, 'context_recall': 1.0000, 'context_precision': 0.7616, 'answer_correctness': 0.6182}

# %%
results_advanced_large = results_advanced_large.to_pandas()
results_advanced_large
# Out:
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /Users/nithin.kamavaram/anaconda3/envs/AIM/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
#                                              question  \
# 0   What is the purpose of the facilities consolid...
# 1   What acquisitions did the company make, includ...
# 2   What types of claims and lawsuits have been fi...
# 3   How are accounts receivable recorded and carri...
# 4   What are some areas in which government author...
# 5   What are the consequences for a company's repu...
# 6   What is the revenue recognition basis at Meta ...
# 7   What are the potential impacts on our products...
# 8   How are gains or losses in interest and other ...
# 9   How does the conversion of Class B common stoc...
# 10  What are the potential consequences of cyber-a...
# 11  What legal actions has the FTC taken regarding...
#
#                                                answer  \
# 0   The purpose of the facilities consolidation re...
# 1   The company made acquisitions including acquir...
# 2   Multiple types of claims and lawsuits have bee...
# 3   Accounts receivable are recorded and carried a...
# 4   Government authorities and regulators are inve...
# 5   The consequences for a company's reputation an...
# 6   The revenue recognition basis at Meta Platform...
# 7   The potential impacts on products and services...
# 8   Gains or losses in interest and other income (...
# 9   The conversion of Class B common stock to Clas...
# 10  The potential consequences of cyber-attacks on...
# 11                                      I don't know.
#
#                                              contexts  \
# 0   [Table of Contents\nNote 3. Restructuring\n202...
# 1   [Europe, and other jurisdictions. Such investi...
# 2   [and certain of our directors and officers all...
# 3   [other unobservable inputs including volatilit...
# 4   [cybersecurity attacks, data privacy violation...
# 5   [Table of Contents\nPayment-related activities...
# 6                                                  []
# 7   [Table of Contents\ndevelopments such as the D...
# 8   [Table of Contents\nidentification method and ...
# 9   [Table of Contents\nNote 4. Earnings per Share...
# 10  [discover all such incidents or activity, whet...
# 11                                                 []
#
#                                          ground_truth  faithfulness  \
# 0   The purpose of the facilities consolidation re...      1.000000
# 1   The company made several acquisitions, includi...      1.000000
# 2   Putative class actions have been filed in the ...      1.000000
# 3   Accounts receivable are recorded and carried a...      1.000000
# 4   government authorities and regulators are inve...      1.000000
# 5   Security breaches, improper access to or discl...      0.857143
# 6   Meta Platforms, Inc. recognizes revenue under ...      1.000000
# 7   The potential impacts on our products and serv...      1.000000
# 8   We include gains or losses in interest and oth...      1.000000
# 9   The conversion of Class B common stock to Clas...      1.000000
# 10  The potential consequences of cyber-attacks on...      1.000000
# 11  The FTC has taken legal actions against the co...           NaN
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           1.000000             1.0           0.833333            0.227668
# 1           0.911045             1.0           1.000000            0.739880
# 2           0.999583             1.0           0.805556            0.590202
# 3           0.983201             1.0           0.500000            0.743609
# 4           0.985153             1.0           1.000000            0.830005
# 5           0.950774             1.0           1.000000            0.782836
# 6           0.955150             1.0           0.000000            0.475201
# 7           0.982916             1.0           1.000000            0.712270
# 8           0.943551             1.0           1.000000            0.743780
# 9           0.993823             1.0           1.000000            0.622227
# 10          0.957704             1.0           1.000000            0.769379
# 11          0.000000             1.0           0.000000            0.181277

# %%
import pandas as pd

# %%
# calculating mean for all the metrics
results1 = results_baseline.describe().loc['mean'].reset_index()
results1.columns = ['Metric', 'method1']
results2 = results_advanced.describe().loc['mean'].reset_index()
results2.columns = ['Metric', 'method2']
results3 = results_advanced_large.describe().loc['mean'].reset_index()
results3.columns = ['Metric', 'method3']

# %%
# merging all dataframes
df_merged = pd.merge(results1, results2, on='Metric')
df_merged = pd.merge(df_merged, results3, on="Metric")
df_merged
# Out:
#                Metric   method1   method2   method3
# 0        faithfulness  1.000000  1.000000  0.987013
# 1    answer_relevancy  0.946302  0.955090  0.888575
# 2      context_recall  0.947368  0.982456  1.000000
# 3   context_precision  0.960648  0.865741  0.761574
# 4  answer_correctness  0.756830  0.636843  0.618194
